# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r'C:\Users\SOFT\Downloads\Walmart.xlsx')

# %%
df
# Out:
#             Order ID Order Date  Ship Date    Customer Name        Country  \
# 0     CA-2013-138688 2013-06-13 2013-06-17  Darrin Van Huff  United States
# 1     CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 2     CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 3     CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 4     CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# ...              ...        ...        ...              ...            ...
# 3198  CA-2013-125794 2013-09-30 2013-10-04     Maris LaWare  United States
# 3199  CA-2014-121258 2014-02-27 2014-03-04      Dave Brooks  United States
# 3200  CA-2014-121258 2014-02-27 2014-03-04      Dave Brooks  United States
# 3201  CA-2014-121258 2014-02-27 2014-03-04      Dave Brooks  United States
# 3202  CA-2014-119914 2014-05-05 2014-05-10     Chris Cortes  United States
#
#              City       State     Category  \
# ...

# %%
## Cleaning the dataset:

# %%
## shape of the dataset:

# %%
df.shape
# Out:
# (3203, 12)

# %%
## Information of the dataset:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3203 entries, 0 to 3202
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       3203 non-null   object
#  1   Order Date     3203 non-null   datetime64[ns]
#  2   Ship Date      3203 non-null   datetime64[ns]
#  3   Customer Name  3203 non-null   object
#  4   Country        3203 non-null   object
#  5   City           3203 non-null   object
#  6   State          3203 non-null   object
#  7   Category       3203 non-null   object
#  8   Product Name   3203 non-null   object
#  9   Sales          3203 non-null   float64
#  10  Quantity       3203 non-null   int64
#  11  Profit         3203 non-null   float64
# dtypes: datetime64[ns](2), float64(2), int64(1), object(7)
# memory usage: 300.4+ KB

# %%
## descriptiton of the dataset:

# %%
df.describe()
# Out:
#                           Order Date                      Ship Date  \
# count                           3203                           3203
# mean   2013-05-10 03:06:07.530440192  2013-05-14 01:25:25.195129600
# min              2011-01-07 00:00:00            2011-01-09 00:00:00
# 25%              2012-05-22 00:00:00            2012-05-26 00:00:00
# 50%              2013-07-22 00:00:00            2013-07-25 00:00:00
# 75%              2014-05-23 00:00:00            2014-05-27 00:00:00
# max              2014-12-31 00:00:00            2015-01-06 00:00:00
# std                              NaN                            NaN
#
#               Sales     Quantity       Profit
# count   3203.000000  3203.000000  3203.000000
# mean     226.493233     3.828910    33.849032
# min        0.990000     1.000000 -3399.980000
# 25%       19.440000     2.000000     3.852000
# 50%       60.840000     3.000000    11.166400
# 75%      215.809000     5.000000    33.000400
# ...

# %%
## checking the null values:

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Customer Name    0
# Country          0
# City             0
# State            0
# Category         0
# Product Name     0
# Sales            0
# Quantity         0
# Profit           0
# dtype: int64

# %%
## checking the duplicated values:

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date    Customer Name        Country  \
# 0  CA-2013-138688 2013-06-13 2013-06-17  Darrin Van Huff  United States
# 1  CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 2  CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 3  CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 4  CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
#
#           City       State     Category  \
# 0  Los Angeles  California       Labels
# 1  Los Angeles  California  Furnishings
# 2  Los Angeles  California          Art
# 3  Los Angeles  California       Phones
# 4  Los Angeles  California      Binders
#
#                                         Product Name    Sales  Quantity  \
# 0  Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 1  Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# ...

# %%
df.dtypes
# Out:
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Customer Name            object
# Country                  object
# City                     object
# State                    object
# Category                 object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Profit                  float64
# dtype: object

# %%
## extract the year from order date:

# %%
df['order_year'] = df['Order Date'].dt.year

# %%
## extract the month from order date:

# %%
df['order_month'] = df['Order Date'].dt.month_name()

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date    Customer Name        Country  \
# 0  CA-2013-138688 2013-06-13 2013-06-17  Darrin Van Huff  United States
# 1  CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 2  CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 3  CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 4  CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
#
#           City       State     Category  \
# 0  Los Angeles  California       Labels
# 1  Los Angeles  California  Furnishings
# 2  Los Angeles  California          Art
# 3  Los Angeles  California       Phones
# 4  Los Angeles  California      Binders
#
#                                         Product Name    Sales  Quantity  \
# 0  Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 1  Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# ...

# %% [markdown]
# EXPLORATORY DATA ANALYSIS:

# %%
## COUNT OF COUNTRY:

# %%
df['Country'].value_counts()
# Out:
# Country
# United States    3203
# Name: count, dtype: int64

# %%
## COUNT OF CITY:

# %%
ai = df['City'].value_counts().nlargest(10)

# %%
ai
# Out:
# City
# Los Angeles      747
# San Francisco    510
# Seattle          428
# San Diego        170
# Phoenix           63
# Denver            44
# San Jose          42
# Springfield       38
# Aurora            34
# Tucson            32
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
i = sns.barplot(x=ai.index,y=ai.values,hue=ai.index)
for i in i.containers:
  plt.bar_label(i)
plt.xticks(rotation=90)
plt.title('count of top 10 cities',color='darkred')
plt.show()

# %%
## COUNT OF STATE:

# %%
df['State'].value_counts()
# Out:
# State
# California    2001
# Washington     506
# Arizona        224
# Colorado       182
# Oregon         124
# Utah            53
# Nevada          39
# New Mexico      37
# Idaho           21
# Montana         15
# Wyoming          1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
g = sns.countplot(x='State',data=df,hue='State')
for i in g.containers:
  plt.bar_label(i)
plt.title('Count of the states',color='blue')
plt.show()

# %%
## COUNT OF CATEGORY:

# %%
df['Category'].value_counts()
# Out:
# Category
# Binders        471
# Paper          450
# Furnishings    304
# Phones         277
# Storage        266
# Accessories    258
# Art            250
# Chairs         207
# Appliances     136
# Labels         116
# Tables         116
# Bookcases       80
# Fasteners       72
# Supplies        69
# Envelopes       67
# Machines        39
# Copiers         25
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
h = sns.countplot(x='Category',data=df,order=df["Category"].value_counts().index[::-1],hue='Category')
for i in h.containers:
  plt.bar_label(i)
plt.xticks(rotation=90)
plt.title('count of categories',color='red')
plt.show()

# %%
hi = df['Product Name'].value_counts().nlargest(10)

# %%
hi
# Out:
# Product Name
# Staples                                            60
# Avery Non-Stick Binders                             8
# Bretford Rectangular Conference Table Tops          7
# Global Troy Executive Leather Low-Back Tilter       7
# SAFCO Arco Folding Chair                            7
# Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl     7
# Vinyl Sectional Post Binders                        7
# Xerox 225                                           7
# Kingston Digital DataTraveler 16GB USB 2.0          6
# GuestStacker Chair with Chrome Finish Legs          6
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
b = sns.barplot(x=hi.index,y=hi.values,hue=hi.index)
for i in b.containers:
  plt.bar_label(i)
plt.xticks(rotation=90)
plt.title('Count of Top 10 product name',color='white',backgroundcolor='black')
b.axes.set_facecolor('cyan')
plt.gcf().set_facecolor('pink')
plt.show()

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date    Customer Name        Country  \
# 0  CA-2013-138688 2013-06-13 2013-06-17  Darrin Van Huff  United States
# 1  CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 2  CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 3  CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 4  CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
#
#           City       State     Category  \
# 0  Los Angeles  California       Labels
# 1  Los Angeles  California  Furnishings
# 2  Los Angeles  California          Art
# 3  Los Angeles  California       Phones
# 4  Los Angeles  California      Binders
#
#                                         Product Name    Sales  Quantity  \
# 0  Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 1  Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# ...

# %%
gi = pd.DataFrame(df[['Order ID',"Customer Name"]].value_counts().nlargest(10))

# %%
## Top 10 Customer which ordered most:

# %%
gi
# Out:
#                                 count
# Order ID       Customer Name
# CA-2013-165330 William Brown       11
# CA-2014-117457 Keith Herrera        9
# CA-2012-164882 Sandra Glassco       9
# CA-2012-104346 Irene Maddox         9
# CA-2011-106439 Greg Guthrie         9
# CA-2011-129364 Tim Brockman         8
# CA-2011-142769 Resi P̦lking        8
# CA-2014-118017 Lena Cacioppo        8
# CA-2014-161956 Dan Reichenbach      8
# CA-2014-156776 Jeremy Lonsdale      8

# %%
plt.figure(figsize=(12,8))
sn = sns.barplot(x="Customer Name",y="count",hue="Customer Name",data=gi)
for i in sn.containers:
  plt.bar_label(i)
plt.xticks(rotation=90)
plt.title('Top 10 Customers which ordered most',color='white',backgroundcolor='darkred')
sn.axes.set_facecolor('pink')
plt.gcf().set_facecolor('yellow')
plt.show()

# %%
## Sales by Profit:

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x='Sales',y='Profit',data=df,marker='o')
plt.title('Sales by Profit ',color='black')
plt.show()

# %%
## sum of sales by month:

# %%
sum_month = df.groupby('order_month')['Sales'].sum().reset_index()

# %%
sum_month['Sales'] = sum_month['Sales'].astype(int)

# %%
sum_month
# Out:
#    order_month   Sales
# 0        April   41966
# 1       August   62674
# 2     December  115934
# 3     February   16268
# 4      January   24918
# 5         July   64706
# 6         June   48519
# 7        March   73023
# 8          May   45320
# 9     November   93068
# 10     October   57436
# 11   September   81618

# %%
plt.figure(figsize=(12,8))
t = sns.barplot(x='order_month',y='Sales',data=sum_month,hue='order_month')
for i in t.containers:
  plt.bar_label(i)
plt.title('sum of sales by month',color='red')
plt.show()

# %%
## sum of sales by year:

# %%
sum_sales_year = df.groupby('order_year')['Sales'].sum().reset_index()

# %%
sum_sales_year
# Out:
#    order_year        Sales
# 0        2011  147883.0330
# 1        2012  139966.2495
# 2        2013  186976.0165
# 3        2014  250632.5255

# %%
plt.figure(figsize=(12,8))
ti = sns.barplot(x='order_year',y='Sales',data=sum_sales_year,hue='order_year')
for i in ti.containers:
  plt.bar_label(i)
plt.title('sum of sales by year',color='red')
plt.show()

# %%
## sum of profit by month:

# %%
sum_profit_month = df.groupby('order_month')['Profit'].sum().reset_index()
sum_profit_month['Profit'] = sum_profit_month['Profit'].astype(int)
sum_profit_month
# Out:
#    order_month  Profit
# 0        April    1428
# 1       August   11077
# 2     December   13258
# 3     February    2699
# 4      January    4565
# 5         July    9282
# 6         June    7730
# 7        March   16094
# 8          May    6800
# 9     November   13130
# 10     October    7655
# 11   September   14694

# %%
plt.figure(figsize=(12,8))
r = sns.barplot(x='order_month',y='Profit',data=sum_profit_month,hue='order_month')
for i in r.containers:
  plt.bar_label(i)
plt.title('sum of profit by month',color='green')
plt.show()

# %%
## sum of profit by year:

# %%
sum_profit_year = df.groupby('order_year')['Profit'].sum().reset_index()

# %%
sum_profit_year
# Out:
#    order_year      Profit
# 0        2011  20065.6912
# 1        2012  20492.1947
# 2        2013  23959.9374
# 3        2014  43900.6256

# %%
plt.figure(figsize=(12,8))
bi = sns.barplot(x='order_year',y='Profit',data=sum_profit_year,hue='order_year')
for i in bi.containers:
  plt.bar_label(i)
plt.title('sum of profit by year',color='green')
plt.show()

# %%
## avg sales by month:

# %%
avg_sales_month = df.groupby('order_month')['Sales'].mean().reset_index()

# %%
avg_sales_month['Sales'] = avg_sales_month['Sales'].astype(int)

# %%
avg_sales_month
# Out:
#    order_month  Sales
# 0        April    218
# 1       August    246
# 2     December    220
# 3     February    164
# 4      January    230
# 5         July    288
# 6         June    239
# 7        March    361
# 8          May    215
# 9     November    210
# 10     October    192
# 11   September    183

# %%
plt.figure(figsize=(12,8))
e = sns.barplot(x='order_month',y='Sales',data=avg_sales_month,hue='order_month')
for i in e.containers:
  plt.bar_label(i)
plt.title('Avg of sales by month',color='red')
plt.show()

# %%
## avg sales by year:

# %%
avg_sales_year = df.groupby('order_year')['Profit'].mean().reset_index()

# %%
avg_sales_year
# Out:
#    order_year     Profit
# 0        2011  30.356568
# 1        2012  31.919306
# 2        2013  29.912531
# 3        2014  39.945974

# %%
plt.figure(figsize=(12,8))
ri = sns.barplot(x='order_year',y='Profit',data=avg_sales_year,hue='order_year')
for i in ri.containers:
  plt.bar_label(i)
plt.title('Avg of sales by year',color='red')
plt.show()

# %%
## avg profit by month:

# %%
avg_profit_month = df.groupby('order_month')['Profit'].mean().reset_index()

# %%
avg_profit_month
# Out:
#    order_month     Profit
# 0        April   7.442086
# 1       August  43.612619
# 2     December  25.254518
# 3     February  27.268580
# 4      January  42.273417
# 5         July  41.441079
# 6         June  38.078819
# 7        March  79.677602
# 8          May  32.383087
# 9     November  29.706379
# 10     October  25.602067
# 11   September  33.022157

# %%
plt.figure(figsize=(12,8))
v = sns.barplot(x='order_month',y='Profit',data=avg_profit_month,hue='order_month')
for i in v.containers:
  plt.bar_label(i)
plt.title('Avg profit by month',color='green')
plt.show()

# %%
## avg profit by year:

# %%
avg_profit_year = df.groupby('order_year')['Profit'].mean().reset_index()

# %%
avg_profit_year
# Out:
#    order_year     Profit
# 0        2011  30.356568
# 1        2012  31.919306
# 2        2013  29.912531
# 3        2014  39.945974

# %%
plt.figure(figsize=(12,8))
fi = sns.barplot(x='order_year',y='Profit',data=avg_profit_year,hue='order_year')
for i in fi.containers:
  plt.bar_label(i)
plt.title('Avg of profit by year',color='green')
plt.show()

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date    Customer Name        Country  \
# 0  CA-2013-138688 2013-06-13 2013-06-17  Darrin Van Huff  United States
# 1  CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 2  CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 3  CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 4  CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
#
#           City       State     Category  \
# 0  Los Angeles  California       Labels
# 1  Los Angeles  California  Furnishings
# 2  Los Angeles  California          Art
# 3  Los Angeles  California       Phones
# 4  Los Angeles  California      Binders
#
#                                         Product Name    Sales  Quantity  \
# 0  Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 1  Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# ...

# %%
## which category has been sold most:

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x='Category',y='Sales',data=df)
plt.xticks(rotation=90)
plt.title('Category by sales',color='blue')
plt.show()

# %%
## which category has been got profit most:

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x='Category',y='Profit',data=df)
plt.xticks(rotation=90)
plt.title('category by profit')
plt.show()

# %%
# in which state profit are most:

# %%
plt.figure(figsize=(12,8))
fi = sns.lineplot(x='State',y='Profit',data=df)
plt.title('Most profit by state',color='green')
plt.show()

# %%
df
# Out:
#             Order ID Order Date  Ship Date    Customer Name        Country  \
# 0     CA-2013-138688 2013-06-13 2013-06-17  Darrin Van Huff  United States
# 1     CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 2     CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 3     CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 4     CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# ...              ...        ...        ...              ...            ...
# 3198  CA-2013-125794 2013-09-30 2013-10-04     Maris LaWare  United States
# 3199  CA-2014-121258 2014-02-27 2014-03-04      Dave Brooks  United States
# 3200  CA-2014-121258 2014-02-27 2014-03-04      Dave Brooks  United States
# 3201  CA-2014-121258 2014-02-27 2014-03-04      Dave Brooks  United States
# 3202  CA-2014-119914 2014-05-05 2014-05-10     Chris Cortes  United States
#
#              City       State     Category  \
# ...

# %%
df["shipping_time_days"] = df["Ship Date"] - df["Order Date"]

# %%
df["shipping_time_days"] = df["shipping_time_days"].dt.days

# %%
df
# Out:
#             Order ID Order Date  Ship Date    Customer Name        Country  \
# 0     CA-2013-138688 2013-06-13 2013-06-17  Darrin Van Huff  United States
# 1     CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 2     CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 3     CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 4     CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# ...              ...        ...        ...              ...            ...
# 3198  CA-2013-125794 2013-09-30 2013-10-04     Maris LaWare  United States
# 3199  CA-2014-121258 2014-02-27 2014-03-04      Dave Brooks  United States
# 3200  CA-2014-121258 2014-02-27 2014-03-04      Dave Brooks  United States
# 3201  CA-2014-121258 2014-02-27 2014-03-04      Dave Brooks  United States
# 3202  CA-2014-119914 2014-05-05 2014-05-10     Chris Cortes  United States
#
#              City       State     Category  \
# ...

# %%
avg_time_by_category = df.groupby('Category')['shipping_time_days'].mean().astype(int).reset_index()

# %%
avg_time_by_category
# Out:
#        Category  shipping_time_days
# 0   Accessories                   3
# 1    Appliances                   4
# 2           Art                   4
# 3       Binders                   3
# 4     Bookcases                   3
# 5        Chairs                   3
# 6       Copiers                   3
# 7     Envelopes                   3
# 8     Fasteners                   3
# 9   Furnishings                   4
# 10       Labels                   4
# 11     Machines                   3
# 12        Paper                   3
# 13       Phones                   4
# 14      Storage                   4
# 15     Supplies                   4
# 16       Tables                   3
