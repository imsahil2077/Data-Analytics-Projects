# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/sales_data.csv')

# %%
df
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# ..          ...         ...       ...    ...           ...            ...
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
## shape of the dataset:

# %%
df.shape
# Out:
# (1000, 14)

# %%
## Information of the dataset:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Product_ID            1000 non-null   int64
#  1   Sale_Date             1000 non-null   object
#  2   Sales_Rep             1000 non-null   object
#  3   Region                1000 non-null   object
#  4   Sales_Amount          1000 non-null   float64
#  5   Quantity_Sold         1000 non-null   int64
#  6   Product_Category      1000 non-null   object
#  7   Unit_Cost             1000 non-null   float64
#  8   Unit_Price            1000 non-null   float64
#  9   Customer_Type         1000 non-null   object
#  10  Discount              1000 non-null   float64
#  11  Payment_Method        1000 non-null   object
#  12  Sales_Channel         1000 non-null   object
#  13  Region_and_Sales_Rep  1000 non-null   object
# dtypes: float64(4), int64(2), object(8)
# ...

# %%
## Description of the dataset:

# %%
df.describe()
# Out:
#         Product_ID  Sales_Amount  Quantity_Sold    Unit_Cost   Unit_Price  \
# count  1000.000000   1000.000000    1000.000000  1000.000000  1000.000000
# mean   1050.128000   5019.265230      25.355000  2475.304550  2728.440120
# std      29.573505   2846.790126      14.159006  1417.872546  1419.399839
# min    1001.000000    100.120000       1.000000    60.280000   167.120000
# 25%    1024.000000   2550.297500      13.000000  1238.380000  1509.085000
# 50%    1051.000000   5019.300000      25.000000  2467.235000  2696.400000
# 75%    1075.000000   7507.445000      38.000000  3702.865000  3957.970000
# max    1100.000000   9989.040000      49.000000  4995.300000  5442.150000
#
#          Discount
# count  1000.00000
# mean      0.15239
# std       0.08720
# min       0.00000
# 25%       0.08000
# 50%       0.15000
# 75%       0.23000
# max       0.30000

# %%
## Drop the unnecessery columns:

# %%
a = ['Product_ID']

# %%
df.drop(a,axis=1,inplace = True)

# %%
b = ['Region_and_Sales_Rep']

# %%
df.drop(b,axis=1,inplace=True)

# %%
df.head()
# Out:
#     Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold Product_Category  \
# 0  2023-02-03       Bob  North       5053.97             18        Furniture
# 1  2023-04-21       Bob   West       4384.02             17        Furniture
# 2  2023-09-21     David  South       4631.23             30             Food
# 3  2023-08-24       Bob  South       2167.94             39         Clothing
# 4  2023-03-24   Charlie   East       3750.20             13      Electronics
#
#    Unit_Cost  Unit_Price Customer_Type  Discount Payment_Method Sales_Channel
# 0     152.75      267.22     Returning      0.09           Cash        Online
# 1    3816.39     4209.44     Returning      0.11           Cash        Retail
# 2     261.56      371.40     Returning      0.20  Bank Transfer        Retail
# 3    4330.03     4467.75           New      0.02    Credit Card        Retail
# 4     637.37      692.71           New      0.08    Credit Card        Online

# %%
df.dtypes
# Out:
# Sale_Date            object
# Sales_Rep            object
# Region               object
# Sales_Amount        float64
# Quantity_Sold         int64
# Product_Category     object
# Unit_Cost           float64
# Unit_Price          float64
# Customer_Type        object
# Discount            float64
# Payment_Method       object
# Sales_Channel        object
# dtype: object

# %%
## checking the null values:

# %%
df.isnull().sum()
# Out:
# Sale_Date           0
# Sales_Rep           0
# Region              0
# Sales_Amount        0
# Quantity_Sold       0
# Product_Category    0
# Unit_Cost           0
# Unit_Price          0
# Customer_Type       0
# Discount            0
# Payment_Method      0
# Sales_Channel       0
# dtype: int64

# %%
df['Sale_Date'] = pd.to_datetime(df['Sale_Date'],errors='coerce')

# %%
df.dtypes
# Out:
# Sale_Date           datetime64[ns]
# Sales_Rep                   object
# Region                      object
# Sales_Amount               float64
# Quantity_Sold                int64
# Product_Category            object
# Unit_Cost                  float64
# Unit_Price                 float64
# Customer_Type               object
# Discount                   float64
# Payment_Method              object
# Sales_Channel               object
# dtype: object

# %%
## Extract the month and day from sale date

# %%
df['Month'] = df['Sale_Date'].dt.month_name()

# %%
df['Day'] = df['Sale_Date'].dt.day_name()

# %%
df['year'] = df['Sale_Date'].dt.year

# %%
df.head()
# Out:
#    Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold Product_Category  \
# 0 2023-02-03       Bob  North       5053.97             18        Furniture
# 1 2023-04-21       Bob   West       4384.02             17        Furniture
# 2 2023-09-21     David  South       4631.23             30             Food
# 3 2023-08-24       Bob  South       2167.94             39         Clothing
# 4 2023-03-24   Charlie   East       3750.20             13      Electronics
#
#    Unit_Cost  Unit_Price Customer_Type  Discount Payment_Method Sales_Channel  \
# 0     152.75      267.22     Returning      0.09           Cash        Online
# 1    3816.39     4209.44     Returning      0.11           Cash        Retail
# 2     261.56      371.40     Returning      0.20  Bank Transfer        Retail
# 3    4330.03     4467.75           New      0.02    Credit Card        Retail
# 4     637.37      692.71           New      0.08    Credit Card        Online
#
#        Month       Day  year
# ...

# %%
## converting float into int values

# %%
df['Sales_Amount'] = df['Sales_Amount'].astype(int)

# %%
df['Unit_Cost'] = df['Unit_Cost'].astype(int)

# %%
df['Unit_Price'] = df['Unit_Price'].astype(int)

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
## Count of Sales rep:

# %%
df['Sales_Rep'].value_counts()
# Out:
# Sales_Rep
# David      222
# Eve        209
# Bob        208
# Alice      192
# Charlie    169
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
ai = sns.countplot(x='Sales_Rep',data=df,hue='Sales_Rep')
for i in ai.containers:
  plt.bar_label(i)
plt.title('Count of Sales Rep',color='blue')
ai.axes.set_facecolor('lightpink')
plt.gcf().set_facecolor('lightyellow')
plt.show()

# %%
## Count of Region :

# %%
df['Region'].value_counts()
# Out:
# Region
# North    267
# East     263
# West     244
# South    226
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
bi = sns.countplot(x='Region',data=df,hue='Region')
for i in bi.containers:
  plt.bar_label(i)
plt.title('Count of Region',color='red')
bi.axes.set_facecolor('lightgreen')
plt.gcf().set_facecolor('lightpink')
plt.show()

# %%
c = df['Region'].value_counts()

# %%
c
# Out:
# Region
# North    267
# East     263
# West     244
# South    226
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.pie(c.values,labels=c.index,autopct='%.1f',labeldistance=1.05,shadow=True)
plt.show()

# %%
## Count of Product category:

# %%
df['Product_Category'].value_counts()
# Out:
# Product_Category
# Clothing       268
# Furniture      260
# Electronics    246
# Food           226
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
li = sns.countplot(x='Product_Category',data=df,hue='Product_Category')
for i in li.containers:
  plt.bar_label(i)
li.axes.set_facecolor('cyan')
plt.gcf().set_facecolor('orange')
plt.title('Count of Product category',color='blue')
plt.show()

# %%
## Percentage of Product Category:

# %%
 h = df['Product_Category'].value_counts()

# %%
h
# Out:
# Product_Category
# Clothing       268
# Furniture      260
# Electronics    246
# Food           226
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.pie(h.values,labels=h.index,autopct='%.1f',labeldistance=1.05,shadow=True)
Center_Circle = plt.Circle((0,0),radius= 0.50,fc = 'white')
fig = plt.gcf()
plt.gca().add_artist(Center_Circle)
plt.show()

# %%
## Count of Customer Type:

# %%
df['Customer_Type'].value_counts()
# Out:
# Customer_Type
# New          504
# Returning    496
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
ci = sns.countplot(x='Customer_Type',data=df,hue='Customer_Type')
for i in ci.containers:
  plt.bar_label(i)
plt.title('Count of Customer Type',color='blue')
plt.show()

# %%
## Count of payment method:

# %%
df['Payment_Method'].value_counts()
# Out:
# Payment_Method
# Credit Card      345
# Bank Transfer    342
# Cash             313
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
fi = sns.countplot(x='Payment_Method',data=df,palette='viridis')
for i in fi.containers:
  plt.bar_label(i)
plt.title('Count of Payment Method',color='red')
plt.show()
# Out:
# <ipython-input-51-89ef98eec9b3>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   fi = sns.countplot(x='Payment_Method',data=df,palette='viridis')

# %%
## Count of Sales Channel:

# %%
df['Sales_Channel'].value_counts()
# Out:
# Sales_Channel
# Retail    512
# Online    488
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
hi = sns.countplot(x='Sales_Channel',data=df,hue='Sales_Channel')
for i in hi.containers:
  plt.bar_label(i)
plt.title('Count of Sales Channel',color='blue')
hi.axes.set_facecolor('cyan')
plt.gcf().set_facecolor('orange')
plt.show()

# %%
df.head()
# Out:
#    Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold Product_Category  \
# 0 2023-02-03       Bob  North          5053             18        Furniture
# 1 2023-04-21       Bob   West          4384             17        Furniture
# 2 2023-09-21     David  South          4631             30             Food
# 3 2023-08-24       Bob  South          2167             39         Clothing
# 4 2023-03-24   Charlie   East          3750             13      Electronics
#
#    Unit_Cost  Unit_Price Customer_Type  Discount Payment_Method Sales_Channel  \
# 0        152         267     Returning      0.09           Cash        Online
# 1       3816        4209     Returning      0.11           Cash        Retail
# 2        261         371     Returning      0.20  Bank Transfer        Retail
# 3       4330        4467           New      0.02    Credit Card        Retail
# 4        637         692           New      0.08    Credit Card        Online
#
#        Month       Day  year
# ...

# %%
df['Profit'] = df['Unit_Price'] * df['Quantity_Sold']

# %%
df.head(5)
# Out:
#    Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold Product_Category  \
# 0 2023-02-03       Bob  North          5053             18        Furniture
# 1 2023-04-21       Bob   West          4384             17        Furniture
# 2 2023-09-21     David  South          4631             30             Food
# 3 2023-08-24       Bob  South          2167             39         Clothing
# 4 2023-03-24   Charlie   East          3750             13      Electronics
#
#    Unit_Cost  Unit_Price Customer_Type  Discount Payment_Method Sales_Channel  \
# 0        152         267     Returning      0.09           Cash        Online
# 1       3816        4209     Returning      0.11           Cash        Retail
# 2        261         371     Returning      0.20  Bank Transfer        Retail
# 3       4330        4467           New      0.02    Credit Card        Retail
# 4        637         692           New      0.08    Credit Card        Online
#
#        Month       Day  year  Profit
# ...

# %%
 b = ['Profit']

# %%
df.drop(b,axis=1,inplace=True)

# %%
df['Profit'] = df['Sales_Amount'] - df['Unit_Price']

# %%
df.head(5)
# Out:
#    Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold Product_Category  \
# 0 2023-02-03       Bob  North          5053             18        Furniture
# 1 2023-04-21       Bob   West          4384             17        Furniture
# 2 2023-09-21     David  South          4631             30             Food
# 3 2023-08-24       Bob  South          2167             39         Clothing
# 4 2023-03-24   Charlie   East          3750             13      Electronics
#
#    Unit_Cost  Unit_Price Customer_Type  Discount Payment_Method Sales_Channel  \
# 0        152         267     Returning      0.09           Cash        Online
# 1       3816        4209     Returning      0.11           Cash        Retail
# 2        261         371     Returning      0.20  Bank Transfer        Retail
# 3       4330        4467           New      0.02    Credit Card        Retail
# 4        637         692           New      0.08    Credit Card        Online
#
#        Month       Day  year  Profit
# ...

# %%
## Average of profit by Region:

# %%
avg_profit_region = df.groupby('Region')['Profit'].mean().reset_index()
avg_profit_region['Profit'] = avg_profit_region['Profit'].round(2)

# %%
avg_profit_region
# Out:
#   Region   Profit
# 0   East  2053.65
# 1  North  2420.24
# 2  South  2403.69
# 3   West  2300.32

# %%
plt.figure(figsize=(12,8))
ti = sns.barplot(x='Region',y='Profit',data=avg_profit_region,palette='viridis')
for i in ti.containers:
  plt.bar_label(i)
plt.title('Average of Profit by Region',color='blue')
plt.show()
# Out:
# <ipython-input-65-449e05fb8e2e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ti = sns.barplot(x='Region',y='Profit',data=avg_profit_region,palette='viridis')

# %%
## Average profit by sales channel:

# %%
avg_profit_salechannel = df.groupby('Sales_Channel')['Profit'].mean().reset_index()
avg_profit_salechannel['Profit'] = avg_profit_salechannel['Profit'].round(2)

# %%
avg_profit_salechannel
# Out:
#   Sales_Channel   Profit
# 0        Online  2249.84
# 1        Retail  2329.89

# %%
plt.figure(figsize=(12,8))
r = sns.barplot(x='Sales_Channel',y='Profit',data=avg_profit_salechannel,hue='Sales_Channel')
for i in r.containers:
  plt.bar_label(i)
plt.title('Avgerage of profit by sales channel',color='blue')
plt.show()

# %%
## Average of sales ammount by region:

# %%
avg_saleammount_region = df.groupby('Region')['Sales_Amount'].mean().reset_index()
avg_saleammount_region['Sales_Amount'] = avg_saleammount_region['Sales_Amount'].round(2)

# %%
avg_saleammount_region
# Out:
#   Region  Sales_Amount
# 0   East       4789.59
# 1  North       5129.14
# 2  South       5106.83
# 3   West       5063.47

# %%
plt.figure(figsize=(12,8))
ri =sns.barplot(x='Region',y='Sales_Amount',data=avg_saleammount_region,palette='viridis')
for i in ri.containers:
  plt.bar_label(i)
plt.title('Average of Sales Amount by Region',color='blue')
plt.show()
# Out:
# <ipython-input-73-91f44307bb1a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ri =sns.barplot(x='Region',y='Sales_Amount',data=avg_saleammount_region,palette='viridis')

# %%
## Profit by year:

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x='year',y='Profit',data=df)
plt.show()

# %%
## Profit by month:

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x='Month',y='Profit',data=df)
plt.show()

# %%
## Profit by Days:

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x='Day',y='Profit',data=df)
plt.show()

# %%
A## avg of profit by year:

# %%
avg_profit_year = df.groupby('year')['Profit'].mean().reset_index()
avg_profit_year['Profit'] = avg_profit_year['Profit'].round(2)

# %%
avg_profit_year
# Out:
#    year   Profit
# 0  2023  2280.89
# 1  2024  5593.33

# %%
plt.figure(figsize=(12,8))
u = sns.barplot(x='year',y='Profit',data=avg_profit_year,hue='year')
for i in u.containers:
  plt.bar_label(i)
plt.title('Average of Profit by year',color='blue')
plt.show()

# %%
## Average of profit by month:

# %%
avg_profit_month = df.groupby('Month')['Profit'].mean().reset_index()
avg_profit_month['Profit'] = avg_profit_month['Profit'].round(2)

# %%
avg_profit_month
# Out:
#         Month   Profit
# 0       April  2620.42
# 1      August  1999.75
# 2    December  1812.64
# 3    February  2308.19
# 4     January  1955.31
# 5        July  2653.28
# 6        June  1811.21
# 7       March  2232.75
# 8         May  2474.40
# 9    November  2583.48
# 10    October  2488.06
# 11  September  2879.40

# %%
plt.figure(figsize=(12,8))
e = sns.barplot(x='Month',y='Profit',data=avg_profit_month,palette=['Black'],order=df['Month'].value_counts().index[::-1])
for i in e.containers:
  plt.bar_label(i)
plt.title('Average of Profit by month',color='red')
plt.show()
# Out:
# <ipython-input-89-8d0953f6c1c3>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   e = sns.barplot(x='Month',y='Profit',data=avg_profit_month,palette=['Black'],order=df['Month'].value_counts().index[::-1])
# <ipython-input-89-8d0953f6c1c3>:2: UserWarning:
# The palette list has fewer values (1) than needed (12) and will cycle, which may produce an uninterpretable plot.
#   e = sns.barplot(x='Month',y='Profit',data=avg_profit_month,palette=['Black'],order=df['Month'].value_counts().index[::-1])

# %%
## Average of profit by days:

# %%
avg_profit_day = df.groupby('Day')['Profit'].mean().reset_index()
avg_profit_day['Profit'] = avg_profit_day['Profit'].round(2)
avg_profit_day
# Out:
#          Day   Profit
# 0     Friday  2029.24
# 1     Monday  2569.37
# 2   Saturday  2497.95
# 3     Sunday  2253.94
# 4   Thursday  2190.57
# 5    Tuesday  2868.07
# 6  Wednesday  1735.79

# %%
plt.figure(figsize=(12,8))
bi = sns.barplot(x='Day',y='Profit',data=avg_profit_day,palette='viridis',order=df['Day'].value_counts().index[::-1])
for i in bi.containers:
  plt.bar_label(i)
plt.title('Average of Profit by Day',color='blue')
plt.show()
# Out:
# <ipython-input-93-bc8a5109a456>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bi = sns.barplot(x='Day',y='Profit',data=avg_profit_day,palette='viridis',order=df['Day'].value_counts().index[::-1])

# %%
df.to_csv('saledata')

# %%
df
