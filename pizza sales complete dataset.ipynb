# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\SOFT\Downloads\pizza_sales .csv')

# %%
df
# Out:
#        pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 0             1         1     hawaiian_m         1  01-01-2015   11:38:36
# 1             2         2  classic_dlx_m         1  01-01-2015   11:57:40
# 2             3         2  five_cheese_l         1  01-01-2015   11:57:40
# 3             4         2    ital_supr_l         1  01-01-2015   11:57:40
# 4             5         2     mexicana_m         1  01-01-2015   11:57:40
# ...         ...       ...            ...       ...         ...        ...
# 48615     48616     21348  ckn_alfredo_m         1  31-12-2015   21:23:10
# 48616     48617     21348  four_cheese_l         1  31-12-2015   21:23:10
# 48617     48618     21348   napolitana_s         1  31-12-2015   21:23:10
# 48618     48619     21349     mexicana_l         1  31-12-2015   22:09:54
# 48619     48620     21350      bbq_ckn_s         1  31-12-2015   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %% [markdown]
# CLEANING THE DATASET:

# %%
## SHAPE OF THE DATASET:

# %%
df.shape
# Out:
# (48620, 12)

# %%
## INFORMATION OF THE DATASET:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
## DESCRIPTION OF THE DATASET:

# %%
df.describe()
# Out:
#            pizza_id      order_id      quantity    unit_price   total_price
# count  48620.000000  48620.000000  48620.000000  48620.000000  48620.000000
# mean   24310.500000  10701.479761      1.019622     16.494132     16.821474
# std    14035.529381   6180.119770      0.143077      3.621789      4.437398
# min        1.000000      1.000000      1.000000      9.750000      9.750000
# 25%    12155.750000   5337.000000      1.000000     12.750000     12.750000
# 50%    24310.500000  10682.500000      1.000000     16.500000     16.500000
# 75%    36465.250000  16100.000000      1.000000     20.250000     20.500000
# max    48620.000000  21350.000000      4.000000     35.950000     83.000000

# %%
## CHECKING THE DUPLICATED VALUES:

# %%
df.duplicated().sum()
# Out:
# 0

# %%
## CHECKING THE NULL VALUES:

# %%
df.isnull().sum()
# Out:
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
df
# Out:
#        pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 0             1         1     hawaiian_m         1  01-01-2015   11:38:36
# 1             2         2  classic_dlx_m         1  01-01-2015   11:57:40
# 2             3         2  five_cheese_l         1  01-01-2015   11:57:40
# 3             4         2    ital_supr_l         1  01-01-2015   11:57:40
# 4             5         2     mexicana_m         1  01-01-2015   11:57:40
# ...         ...       ...            ...       ...         ...        ...
# 48615     48616     21348  ckn_alfredo_m         1  31-12-2015   21:23:10
# 48616     48617     21348  four_cheese_l         1  31-12-2015   21:23:10
# 48617     48618     21348   napolitana_s         1  31-12-2015   21:23:10
# 48618     48619     21349     mexicana_l         1  31-12-2015   22:09:54
# 48619     48620     21350      bbq_ckn_s         1  31-12-2015   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
## DROP THE UNNECCESSERY COLUMN:

# %%
gi = ['pizza_id','pizza_name_id']

# %%
df.drop(gi,axis=1,inplace=True)

# %%
df
# Out:
#        order_id  quantity  order_date order_time  unit_price  total_price  \
# 0             1         1  01-01-2015   11:38:36       13.25        13.25
# 1             2         1  01-01-2015   11:57:40       16.00        16.00
# 2             2         1  01-01-2015   11:57:40       18.50        18.50
# 3             2         1  01-01-2015   11:57:40       20.75        20.75
# 4             2         1  01-01-2015   11:57:40       16.00        16.00
# ...         ...       ...         ...        ...         ...          ...
# 48615     21348         1  31-12-2015   21:23:10       16.75        16.75
# 48616     21348         1  31-12-2015   21:23:10       17.95        17.95
# 48617     21348         1  31-12-2015   21:23:10       12.00        12.00
# 48618     21349         1  31-12-2015   22:09:54       20.25        20.25
# 48619     21350         1  31-12-2015   23:02:05       12.75        12.75
#
#       pizza_size pizza_category  \
# 0              M        Classic
# ...

# %%
df['proper_date_time'] =  df['order_date'] + ' ' + df['order_time']

# %%
df['proper_date_time'] = pd.to_datetime(df['proper_date_time'],dayfirst=True)

# %%
df
# Out:
#        order_id  quantity  order_date order_time  unit_price  total_price  \
# 0             1         1  01-01-2015   11:38:36       13.25        13.25
# 1             2         1  01-01-2015   11:57:40       16.00        16.00
# 2             2         1  01-01-2015   11:57:40       18.50        18.50
# 3             2         1  01-01-2015   11:57:40       20.75        20.75
# 4             2         1  01-01-2015   11:57:40       16.00        16.00
# ...         ...       ...         ...        ...         ...          ...
# 48615     21348         1  31-12-2015   21:23:10       16.75        16.75
# 48616     21348         1  31-12-2015   21:23:10       17.95        17.95
# 48617     21348         1  31-12-2015   21:23:10       12.00        12.00
# 48618     21349         1  31-12-2015   22:09:54       20.25        20.25
# 48619     21350         1  31-12-2015   23:02:05       12.75        12.75
#
#       pizza_size pizza_category  \
# 0              M        Classic
# ...

# %%
df['year'] = df['proper_date_time'].dt.year

# %%
df
# Out:
#        order_id  quantity  order_date order_time  unit_price  total_price  \
# 0             1         1  01-01-2015   11:38:36       13.25        13.25
# 1             2         1  01-01-2015   11:57:40       16.00        16.00
# 2             2         1  01-01-2015   11:57:40       18.50        18.50
# 3             2         1  01-01-2015   11:57:40       20.75        20.75
# 4             2         1  01-01-2015   11:57:40       16.00        16.00
# ...         ...       ...         ...        ...         ...          ...
# 48615     21348         1  31-12-2015   21:23:10       16.75        16.75
# 48616     21348         1  31-12-2015   21:23:10       17.95        17.95
# 48617     21348         1  31-12-2015   21:23:10       12.00        12.00
# 48618     21349         1  31-12-2015   22:09:54       20.25        20.25
# 48619     21350         1  31-12-2015   23:02:05       12.75        12.75
#
#       pizza_size pizza_category  \
# 0              M        Classic
# ...

# %%
df['month'] = df['proper_date_time'].dt.month_name()

# %%
df
# Out:
#        order_id  quantity  order_date order_time  unit_price  total_price  \
# 0             1         1  01-01-2015   11:38:36       13.25        13.25
# 1             2         1  01-01-2015   11:57:40       16.00        16.00
# 2             2         1  01-01-2015   11:57:40       18.50        18.50
# 3             2         1  01-01-2015   11:57:40       20.75        20.75
# 4             2         1  01-01-2015   11:57:40       16.00        16.00
# ...         ...       ...         ...        ...         ...          ...
# 48615     21348         1  31-12-2015   21:23:10       16.75        16.75
# 48616     21348         1  31-12-2015   21:23:10       17.95        17.95
# 48617     21348         1  31-12-2015   21:23:10       12.00        12.00
# 48618     21349         1  31-12-2015   22:09:54       20.25        20.25
# 48619     21350         1  31-12-2015   23:02:05       12.75        12.75
#
#       pizza_size pizza_category  \
# 0              M        Classic
# ...

# %%
df['day'] = df['proper_date_time'].dt.day_name()

# %%
df
# Out:
#        order_id  quantity  order_date order_time  unit_price  total_price  \
# 0             1         1  01-01-2015   11:38:36       13.25        13.25
# 1             2         1  01-01-2015   11:57:40       16.00        16.00
# 2             2         1  01-01-2015   11:57:40       18.50        18.50
# 3             2         1  01-01-2015   11:57:40       20.75        20.75
# 4             2         1  01-01-2015   11:57:40       16.00        16.00
# ...         ...       ...         ...        ...         ...          ...
# 48615     21348         1  31-12-2015   21:23:10       16.75        16.75
# 48616     21348         1  31-12-2015   21:23:10       17.95        17.95
# 48617     21348         1  31-12-2015   21:23:10       12.00        12.00
# 48618     21349         1  31-12-2015   22:09:54       20.25        20.25
# 48619     21350         1  31-12-2015   23:02:05       12.75        12.75
#
#       pizza_size pizza_category  \
# 0              M        Classic
# ...

# %% [markdown]
# EXPLORATORY DATA ANALYSIS:

# %%
## count of pizza name:

# %%
df['pizza_name'].value_counts()
# Out:
# pizza_name
# The Classic Deluxe Pizza                      2416
# The Barbecue Chicken Pizza                    2372
# The Hawaiian Pizza                            2370
# The Pepperoni Pizza                           2369
# The Thai Chicken Pizza                        2315
# The California Chicken Pizza                  2302
# The Sicilian Pizza                            1887
# The Spicy Italian Pizza                       1887
# The Southwest Chicken Pizza                   1885
# The Four Cheese Pizza                         1850
# The Italian Supreme Pizza                     1849
# The Big Meat Pizza                            1811
# The Vegetables + Vegetables Pizza             1510
# The Mexicana Pizza                            1456
# The Napolitana Pizza                          1451
# The Spinach and Feta Pizza                    1432
# The Prosciutto and Arugula Pizza              1428
# The Pepper Salami Pizza                       1422
# ...

# %%
plt.figure(figsize=(15,10))
hi = sns.countplot(x='pizza_name',data=df,hue='pizza_name')
for i in hi.containers:
  plt.bar_label(i)
plt.xticks(rotation=90)
hi.axes.set_facecolor('orange')
plt.gcf().set_facecolor('yellow')
plt.title('count of pizza name',color='green')
plt.show()

# %%
## count of pizza ingredeints:

# %%
si =df['pizza_ingredients'].value_counts().nlargest(10)

# %%
si
# Out:
# pizza_ingredients
# Pepperoni, Mushrooms, Red Onions, Red Peppers, Bacon                                                 2416
# Barbecued Chicken, Red Peppers, Green Peppers, Tomatoes, Red Onions, Barbecue Sauce                  2372
# Sliced Ham, Pineapple, Mozzarella Cheese                                                             2370
# Mozzarella Cheese, Pepperoni                                                                         2369
# Chicken, Pineapple, Tomatoes, Red Peppers, Thai Sweet Chilli Sauce                                   2315
# Chicken, Artichoke, Spinach, Garlic, Jalapeno Peppers, Fontina Cheese, Gouda Cheese                  2302
# Coarse Sicilian Salami, Tomatoes, Green Olives, Luganega Sausage, Onions, Garlic                     1887
# Capocollo, Tomatoes, Goat Cheese, Artichokes, Peperoncini verdi, Garlic                              1887
# Chicken, Tomatoes, Red Peppers, Red Onions, Jalapeno Peppers, Corn, Cilantro, Chipotle Sauce         1885
# ...

# %%
plt.figure(figsize=(15,10))
ji = sns.barplot(x=si.index,y=si.values)
for i in ji.containers:
  plt.bar_label(i)
plt.xticks(rotation=90)
ji.axes.set_facecolor('cyan')
plt.gcf().set_facecolor('pink')
plt.title('Count of top 10 pizza ingredients',color='blue')
plt.show()

# %%
## count of pizza category:

# %%
df['pizza_category'].value_counts()
# Out:
# pizza_category
# Classic    14579
# Supreme    11777
# Veggie     11449
# Chicken    10815
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
ki = sns.countplot(x='pizza_category',data=df,hue='pizza_category')
for i in ki.containers:
  plt.bar_label(i)
plt.title('count of pizza category',color='orange',backgroundcolor='black')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## percentage of pizza category:

# %%
n = df['pizza_category'].value_counts()

# %%
n
# Out:
# pizza_category
# Classic    14579
# Supreme    11777
# Veggie     11449
# Chicken    10815
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.pie(n.values,labels=n.index,autopct='%.1f',labeldistance=1.05,shadow = True)
plt.title('percentage of pizza category',color='red')
plt.show()

# %%
## count of pizza size:

# %%
df['pizza_size'].value_counts()
# Out:
# pizza_size
# L      18526
# M      15385
# S      14137
# XL       544
# XXL       28
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
b = sns.countplot(x='pizza_size',data=df,hue='pizza_size')
for i in b.containers:
  plt.bar_label(i)
plt.title('count of pizza size',color='blue')
plt.show()

# %%
## percentage of pizza size:

# %%
v = df['pizza_size'].value_counts()

# %%
plt.figure(figsize=(12,8))
plt.pie(v.values,labels=v.index,autopct='%.1f',shadow=True)
center_circle = plt.Circle((0,0),radius = 0.50,fc='white')
fig = plt.gcf()
plt.gca().add_artist(center_circle)

plt.title('percentage of pizza size',color='red')
plt.show()

# %%
df.head()
# Out:
#    order_id  quantity  order_date order_time  unit_price  total_price  \
# 0         1         1  01-01-2015   11:38:36       13.25        13.25
# 1         2         1  01-01-2015   11:57:40       16.00        16.00
# 2         2         1  01-01-2015   11:57:40       18.50        18.50
# 3         2         1  01-01-2015   11:57:40       20.75        20.75
# 4         2         1  01-01-2015   11:57:40       16.00        16.00
#
#   pizza_size pizza_category  \
# 0          M        Classic
# 1          M        Classic
# 2          L         Veggie
# 3          L        Supreme
# 4          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
# ...

# %%
## Sum of total price by pizza name:

# %%
sum_of_price_by_pizza_name = df.groupby('pizza_name')['total_price'].sum().reset_index()

# %%
sum_of_price_by_pizza_name
# Out:
#                                     pizza_name  total_price
# 0                   The Barbecue Chicken Pizza     42768.00
# 1                           The Big Meat Pizza     22968.00
# 2                         The Brie Carre Pizza     11588.50
# 3                          The Calabrese Pizza     15934.25
# 4                 The California Chicken Pizza     41409.50
# 5                    The Chicken Alfredo Pizza     16900.25
# 6                      The Chicken Pesto Pizza     16701.75
# 7                     The Classic Deluxe Pizza     38180.50
# 8                        The Five Cheese Pizza     26066.50
# 9                        The Four Cheese Pizza     32265.70
# 10                             The Greek Pizza     28454.10
# 11                      The Green Garden Pizza     13955.75
# 12                          The Hawaiian Pizza     32273.25
# 13                 The Italian Capocollo Pizza     25094.00
# 14                   The Italian Supreme Pizza     33476.75
# ...

# %%
plt.figure(figsize=(20,15))
ti = sns.barplot(x='pizza_name',y='total_price',data=sum_of_price_by_pizza_name,palette='crest')
for i in ti.containers:
  plt.bar_label(i,rotation=90)
plt.xticks(rotation=90)
plt.title('sum of price by pizza name',color='green')
plt.show()
# Out:
# C:\Users\SOFT\AppData\Local\Temp\ipykernel_12276\4219877084.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ti = sns.barplot(x='pizza_name',y='total_price',data=sum_of_price_by_pizza_name,palette='crest')

# %%
## Average of total price by pizza name:

# %%
average_price_by_pizzaname = df.groupby('pizza_name')['total_price'].mean().reset_index()
average_price_by_pizzaname['total_price'] = average_price_by_pizzaname['total_price'].astype(int)

# %%
average_price_by_pizzaname
# Out:
#                                     pizza_name  total_price
# 0                   The Barbecue Chicken Pizza           18
# 1                           The Big Meat Pizza           12
# 2                         The Brie Carre Pizza           24
# 3                          The Calabrese Pizza           17
# 4                 The California Chicken Pizza           17
# 5                    The Chicken Alfredo Pizza           17
# 6                      The Chicken Pesto Pizza           17
# 7                     The Classic Deluxe Pizza           15
# 8                        The Five Cheese Pizza           19
# 9                        The Four Cheese Pizza           17
# 10                             The Greek Pizza           20
# 11                      The Green Garden Pizza           14
# 12                          The Hawaiian Pizza           13
# 13                 The Italian Capocollo Pizza           17
# 14                   The Italian Supreme Pizza           18
# ...

# %%
plt.figure(figsize=(20,15))
fi = sns.barplot(x='pizza_name',y='total_price',data=average_price_by_pizzaname,palette='crest')
for i in fi.containers:
  plt.bar_label(i)
plt.xticks(rotation=90)
plt.title('Avg of total price by pizza name',color='red')
plt.show()
# Out:
# C:\Users\SOFT\AppData\Local\Temp\ipykernel_12276\3017377871.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   fi = sns.barplot(x='pizza_name',y='total_price',data=average_price_by_pizzaname,palette='crest')

# %%
df['pizza_ingredients'].unique()
# Out:
# array(['Sliced Ham, Pineapple, Mozzarella Cheese',
#        'Pepperoni, Mushrooms, Red Onions, Red Peppers, Bacon',
#        'Mozzarella Cheese, Provolone Cheese, Smoked Gouda Cheese, Romano Cheese, Blue Cheese, Garlic',
#        'Calabrese Salami, Capocollo, Tomatoes, Red Onions, Green Olives, Garlic',
#        'Tomatoes, Red Peppers, Jalapeno Peppers, Red Onions, Cilantro, Corn, Chipotle Sauce, Garlic',
#        'Chicken, Pineapple, Tomatoes, Red Peppers, Thai Sweet Chilli Sauce',
#        'Prosciutto di San Daniele, Arugula, Mozzarella Cheese',
#        'Barbecued Chicken, Red Peppers, Green Peppers, Tomatoes, Red Onions, Barbecue Sauce',
#        'Kalamata Olives, Feta Cheese, Tomatoes, Garlic, Beef Chuck Roast, Red Onions',
#        'Spinach, Red Onions, Pepperoni, Tomatoes, Artichokes, Kalamata Olives, Garlic, Asiago Cheese',
#        'Spinach, Mushrooms, Tomatoes, Green Olives, Feta Cheese',
#        'Capocollo, Red Peppers, Tomatoes, Goat Cheese, Garlic, Oregano',
# ...

# %%
def replace_values(old,new):
  df['pizza_ingredients'] = df['pizza_ingredients'].str.replace(old,new)

# %%
replace_values('?duja Salami','Nduja Salami')

# %%
## sum of total price by pizza ingredients:

# %%
sum_totalprice_pizza_ingredients = df.groupby('pizza_ingredients')['total_price'].sum().reset_index()

# %%
sum_totalprice_pizza_ingredients
# Out:
#                                     pizza_ingredients  total_price
# 0   Bacon, Pepperoni, Italian Sausage, Chorizo Sau...     22968.00
# 1   Barbecued Chicken, Red Peppers, Green Peppers,...     42768.00
# 2   Brie Carre Cheese, Prosciutto, Caramelized Oni...     11588.50
# 3   Calabrese Salami, Capocollo, Tomatoes, Red Oni...     33476.75
# 4   Capocollo, Red Peppers, Tomatoes, Goat Cheese,...     25094.00
# 5   Capocollo, Tomatoes, Goat Cheese, Artichokes, ...     34831.25
# 6   Chicken, Artichoke, Spinach, Garlic, Jalapeno ...     41409.50
# 7   Chicken, Pineapple, Tomatoes, Red Peppers, Tha...     43434.25
# 8   Chicken, Red Onions, Red Peppers, Mushrooms, A...     16900.25
# 9   Chicken, Tomatoes, Red Peppers, Red Onions, Ja...     34705.75
# 10  Chicken, Tomatoes, Red Peppers, Spinach, Garli...     16701.75
# 11  Coarse Sicilian Salami, Tomatoes, Green Olives...     30940.50
# 12  Eggplant, Artichokes, Tomatoes, Zucchini, Red ...     16019.25
# ...

# %%
plt.figure(figsize=(20,15))
e = sns.barplot(x='pizza_ingredients',y='total_price',data=sum_totalprice_pizza_ingredients)
for i in e.containers:
  plt.bar_label(i)
plt.xticks(rotation=90)
plt.title('sum of total price by pizza ingredients',color='darkred')
plt.show()

# %%
avg_totalprice_by_pizza_ingredients = df.groupby('pizza_ingredients')['total_price'].mean().reset_index()
avg_totalprice_by_pizza_ingredients['total_price'] = df['total_price'].astype(int)

# %%
avg_totalprice_by_pizza_ingredients
# Out:
#                                     pizza_ingredients  total_price
# 0   Bacon, Pepperoni, Italian Sausage, Chorizo Sau...           13
# 1   Barbecued Chicken, Red Peppers, Green Peppers,...           16
# 2   Brie Carre Cheese, Prosciutto, Caramelized Oni...           18
# 3   Calabrese Salami, Capocollo, Tomatoes, Red Oni...           20
# 4   Capocollo, Red Peppers, Tomatoes, Goat Cheese,...           16
# 5   Capocollo, Tomatoes, Goat Cheese, Artichokes, ...           20
# 6   Chicken, Artichoke, Spinach, Garlic, Jalapeno ...           16
# 7   Chicken, Pineapple, Tomatoes, Red Peppers, Tha...           20
# 8   Chicken, Red Onions, Red Peppers, Mushrooms, A...           16
# 9   Chicken, Tomatoes, Red Peppers, Red Onions, Ja...           16
# 10  Chicken, Tomatoes, Red Peppers, Spinach, Garli...           12
# 11  Coarse Sicilian Salami, Tomatoes, Green Olives...           12
# 12  Eggplant, Artichokes, Tomatoes, Zucchini, Red ...           12
# ...

# %%
plt.figure(figsize=(20,15))
x = sns.barplot(x='pizza_ingredients',y='total_price',data=avg_totalprice_by_pizza_ingredients)
for i in x.containers:
  plt.bar_label(i)
plt.xticks(rotation=90)
plt.title('Avg of total price by pizza ingredients',color='red')
plt.show()

# %%
df.head()
# Out:
#    order_id  quantity  order_date order_time  unit_price  total_price  \
# 0         1         1  01-01-2015   11:38:36       13.25        13.25
# 1         2         1  01-01-2015   11:57:40       16.00        16.00
# 2         2         1  01-01-2015   11:57:40       18.50        18.50
# 3         2         1  01-01-2015   11:57:40       20.75        20.75
# 4         2         1  01-01-2015   11:57:40       16.00        16.00
#
#   pizza_size pizza_category  \
# 0          M        Classic
# 1          M        Classic
# 2          L         Veggie
# 3          L        Supreme
# 4          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
# ...

# %%
## pizza category by order id:

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x='pizza_category',y='order_id',data=df,marker = 'o')
# Out:
# <Axes: xlabel='pizza_category', ylabel='order_id'>

# %%
## Average o total price by pizza category:

# %%
avg_totalprice_pizzacategory = df.groupby('pizza_category')['total_price'].mean().reset_index()

# %%
avg_totalprice_pizzacategory
# Out:
#   pizza_category  total_price
# 0        Chicken    18.115534
# 1        Classic    15.093840
# 2        Supreme    17.678271
# 3         Veggie    16.917674

# %%
plt.figure(figsize=(12,8))
y = sns.barplot(x='pizza_category',y='total_price',data=avg_totalprice_pizzacategory,hue='pizza_category')
for i in y.containers:
  plt.bar_label(i)
plt.title('Avg of total price by pizza category',color='orange',backgroundcolor='black')
plt.show()

# %%
## order id by month

# %%
df
# Out:
#        order_id  quantity  order_date order_time  unit_price  total_price  \
# 0             1         1  01-01-2015   11:38:36       13.25        13.25
# 1             2         1  01-01-2015   11:57:40       16.00        16.00
# 2             2         1  01-01-2015   11:57:40       18.50        18.50
# 3             2         1  01-01-2015   11:57:40       20.75        20.75
# 4             2         1  01-01-2015   11:57:40       16.00        16.00
# ...         ...       ...         ...        ...         ...          ...
# 48615     21348         1  31-12-2015   21:23:10       16.75        16.75
# 48616     21348         1  31-12-2015   21:23:10       17.95        17.95
# 48617     21348         1  31-12-2015   21:23:10       12.00        12.00
# 48618     21349         1  31-12-2015   22:09:54       20.25        20.25
# 48619     21350         1  31-12-2015   23:02:05       12.75        12.75
#
#       pizza_size pizza_category  \
# 0              M        Classic
# ...

# %%
pizza_sold_onth = df.groupby("month")["quantity"].sum().reset_index()

# %%
pizza_sold_onth
# Out:
#         month  quantity
# 0       April      4151
# 1      August      4168
# 2    December      3935
# 3    February      3961
# 4     January      4232
# 5        July      4392
# 6        June      4107
# 7       March      4261
# 8         May      4328
# 9    November      4266
# 10    October      3883
# 11  September      3890

# %%
## which day pizza is most ordered?

# %%
plt.figure(figsize=(12,8))
xi = sns.barplot(x='day',y='order_id',data=df,palette='crest')
for i in xi.containers:
  plt.bar_label(i,rotation=90)
plt.title('which day pizza is most ordered',color='orange',backgroundcolor='black')
plt.show()
# Out:
# C:\Users\SOFT\AppData\Local\Temp\ipykernel_12276\2437836732.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   xi = sns.barplot(x='day',y='order_id',data=df,palette='crest')

# %%
df['total_price'] = df['total_price'] = pd.to_numeric(df['total_price'])

# %%
df['sales'] = df['quantity'] * df['total_price']

# %%
df.head()
# Out:
#    order_id  quantity  order_date order_time  unit_price  total_price  \
# 0         1         1  01-01-2015   11:38:36       13.25        13.25
# 1         2         1  01-01-2015   11:57:40       16.00        16.00
# 2         2         1  01-01-2015   11:57:40       18.50        18.50
# 3         2         1  01-01-2015   11:57:40       20.75        20.75
# 4         2         1  01-01-2015   11:57:40       16.00        16.00
#
#   pizza_size pizza_category  \
# 0          M        Classic
# 1          M        Classic
# 2          L         Veggie
# 3          L        Supreme
# 4          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
# ...

# %%
sum_of_sales = df.groupby('month')['sales'].sum().reset_index()

# %%
sum_of_sales
# Out:
#         month     sales
# 0       April  71638.00
# 1      August  70721.15
# 2    December  67235.45
# 3    February  67409.00
# 4     January  72534.50
# 5        July  75650.80
# 6        June  71147.00
# 7       March  72867.30
# 8         May  74467.05
# 9    November  73172.55
# 10    October  67099.30
# 11  September  66693.65

# %%
## sum of sales by month:

# %%
plt.figure(figsize=(12,8))
m = sns.barplot(x='month',y='sales',data=sum_of_sales,hue='month')
for i in m.containers:
  plt.bar_label(i)
plt.title('sum of sales by month',color='orange',backgroundcolor='black')

plt.show()

# %%
## sum of sales by day:

# %%
sum_of_sales_day = df.groupby('day')['sales'].sum().reset_index()

# %%
sum_of_sales_day
# Out:
#          day      sales
# 0     Friday  140837.40
# 1     Monday  111395.35
# 2   Saturday  128049.10
# 3     Sunday  103225.00
# 4   Thursday  128866.10
# 5    Tuesday  118944.00
# 6  Wednesday  119318.80

# %%
plt.figure(figsize=(12,8))
g= sns.barplot(x='day',y='sales',data=sum_of_sales_day,hue='day')
for i in g.containers:
  plt.bar_label(i)
plt.title('sum of sales by day',color='orange',backgroundcolor='black')
plt.show()
