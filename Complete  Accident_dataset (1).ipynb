# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r'C:\Users\SOFT\Downloads\Road Accident Data.xlsx')

# %%
df
# Out:
#        Accident_Index Accident Date  Year              Junction_Control  \
# 0       200901BS70001    2021-01-01  2021      Give way or uncontrolled
# 1       200901BS70002    2021-01-05  2021      Give way or uncontrolled
# 2       200901BS70003    2021-01-04  2021      Give way or uncontrolled
# 3       200901BS70004    2021-01-05  2021           Auto traffic signal
# 4       200901BS70005    2021-01-06  2021           Auto traffic signal
# ...               ...           ...   ...                           ...
# 307968  201091NM01760    2022-02-18  2022  Data missing or out of range
# 307969  201091NM01881    2022-02-21  2022  Data missing or out of range
# 307970  201091NM01935    2022-02-23  2022      Give way or uncontrolled
# 307971  201091NM01964    2022-02-23  2022      Give way or uncontrolled
# 307972  201091NM02142    2022-02-28  2022      Give way or uncontrolled
#
#                             Junction_Detail Accident_Severity  \
# ...

# %%
## cleaning the dataset:

# %%
## shape of the dataset:

# %%
df.shape
# Out:
# (307973, 17)

# %%
## informantion of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307973 entries, 0 to 307972
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Accident_Index              307973 non-null  object
#  1   Accident Date               307973 non-null  datetime64[ns]
#  2   Year                        307973 non-null  int64
#  3   Junction_Control            307973 non-null  object
#  4   Junction_Detail             307973 non-null  object
#  5   Accident_Severity           307973 non-null  object
#  6   Light_Conditions            307973 non-null  object
#  7   Local_Authority_(District)  307973 non-null  object
#  8   Number_of_Casualties        307973 non-null  int64
#  9   Number_of_Vehicles          307973 non-null  int64
#  10  Road_Surface_Conditions     307656 non-null  object
#  11  Road_Type                   306439 non-null  object
# ...

# %%
## description of the dataset:

# %%
df.describe()
# Out:
#                        Accident Date           Year  Number_of_Casualties  \
# count                         307973  307973.000000         307973.000000
# mean   2021-12-23 22:19:39.804722944    2021.468934              1.356882
# min              2021-01-01 00:00:00    2021.000000              1.000000
# 25%              2021-06-28 00:00:00    2021.000000              1.000000
# 50%              2021-12-08 00:00:00    2021.000000              1.000000
# 75%              2022-06-25 00:00:00    2022.000000              1.000000
# max              2022-12-31 00:00:00    2022.000000             48.000000
# std                              NaN       0.499035              0.815857
#
#        Number_of_Vehicles    Speed_limit
# count       307973.000000  307973.000000
# mean             1.829063      38.866037
# min              1.000000      10.000000
# 25%              1.000000      30.000000
# 50%              2.000000      30.000000
# 75%              2.000000      50.000000
# ...

# %%
## types of the dataset:

# %%
df.dtypes
# Out:
# Accident_Index                        object
# Accident Date                 datetime64[ns]
# Year                                   int64
# Junction_Control                      object
# Junction_Detail                       object
# Accident_Severity                     object
# Light_Conditions                      object
# Local_Authority_(District)            object
# Number_of_Casualties                   int64
# Number_of_Vehicles                     int64
# Road_Surface_Conditions               object
# Road_Type                             object
# Speed_limit                            int64
# Time                                  object
# Urban_or_Rural_Area                   object
# Weather_Conditions                    object
# Vehicle_Type                          object
# dtype: object

# %%
## checking the null values in the dataset:

# %%
df.isnull().sum()
# Out:
# Accident_Index                   0
# Accident Date                    0
# Year                             0
# Junction_Control                 0
# Junction_Detail                  0
# Accident_Severity                0
# Light_Conditions                 0
# Local_Authority_(District)       0
# Number_of_Casualties             0
# Number_of_Vehicles               0
# Road_Surface_Conditions        317
# Road_Type                     1534
# Speed_limit                      0
# Time                            17
# Urban_or_Rural_Area              0
# Weather_Conditions            6057
# Vehicle_Type                     0
# dtype: int64

# %%
df.head()
# Out:
#   Accident_Index Accident Date  Year          Junction_Control  \
# 0  200901BS70001    2021-01-01  2021  Give way or uncontrolled
# 1  200901BS70002    2021-01-05  2021  Give way or uncontrolled
# 2  200901BS70003    2021-01-04  2021  Give way or uncontrolled
# 3  200901BS70004    2021-01-05  2021       Auto traffic signal
# 4  200901BS70005    2021-01-06  2021       Auto traffic signal
#
#            Junction_Detail Accident_Severity       Light_Conditions  \
# 0  T or staggered junction           Serious               Daylight
# 1               Crossroads           Serious               Daylight
# 2  T or staggered junction            Slight               Daylight
# 3  T or staggered junction           Serious               Daylight
# 4               Crossroads           Serious  Darkness - lights lit
#
#   Local_Authority_(District)  Number_of_Casualties  Number_of_Vehicles  \
# 0     Kensington and Chelsea                     1                   2
# ...

# %%
## fill the null values in categorical columns:

# %%
df['Road_Surface_Conditions'] = df['Road_Surface_Conditions'].fillna(df['Road_Surface_Conditions'].mode()[0])

# %%
df['Road_Type'] = df['Road_Type'].fillna(df['Road_Type'].mode()[0])

# %%
df['Weather_Conditions'] = df['Weather_Conditions'].fillna(df['Weather_Conditions'].mode()[0])

# %%
df['hour'] = pd.to_datetime(df["Time"], format='%H:%M:%S').dt.hour

# %%
df["Time"].dtype
# Out:
# dtype('O')

# %%
## extract the year month and day from Accedent date:

# %%
df['accident_day'] = df['Accident Date'].dt.day_name()

# %%
df.head()
# Out:
#   Accident_Index Accident Date  Year          Junction_Control  \
# 0  200901BS70001    2021-01-01  2021  Give way or uncontrolled
# 1  200901BS70002    2021-01-05  2021  Give way or uncontrolled
# 2  200901BS70003    2021-01-04  2021  Give way or uncontrolled
# 3  200901BS70004    2021-01-05  2021       Auto traffic signal
# 4  200901BS70005    2021-01-06  2021       Auto traffic signal
#
#            Junction_Detail Accident_Severity       Light_Conditions  \
# 0  T or staggered junction           Serious               Daylight
# 1               Crossroads           Serious               Daylight
# 2  T or staggered junction            Slight               Daylight
# 3  T or staggered junction           Serious               Daylight
# 4               Crossroads           Serious  Darkness - lights lit
#
#   Local_Authority_(District)  Number_of_Casualties  Number_of_Vehicles  \
# 0     Kensington and Chelsea                     1                   2
# ...

# %%
## count of Junction Control:

# %%
df['Junction_Control'].value_counts()
# Out:
# Junction_Control
# Give way or uncontrolled               150045
# Data missing or out of range            98056
# Auto traffic signal                     32349
# Not at junction or within 20 metres     25378
# Stop sign                                1685
# Authorised person                         460
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
a = sns.countplot(x='Junction_Control',data=df,hue='Junction_Control')
for i in a.containers:
  plt.bar_label(i)
plt.xticks(rotation=90)
plt.title('Count of Junction Control',color='red')
a.axes.set_facecolor('pink')
plt.gcf().set_facecolor('cyan')
plt.show()

# %%
df.head()
# Out:
#   Accident_Index Accident Date  Year          Junction_Control  \
# 0  200901BS70001    2021-01-01  2021  Give way or uncontrolled
# 1  200901BS70002    2021-01-05  2021  Give way or uncontrolled
# 2  200901BS70003    2021-01-04  2021  Give way or uncontrolled
# 3  200901BS70004    2021-01-05  2021       Auto traffic signal
# 4  200901BS70005    2021-01-06  2021       Auto traffic signal
#
#            Junction_Detail Accident_Severity       Light_Conditions  \
# 0  T or staggered junction           Serious               Daylight
# 1               Crossroads           Serious               Daylight
# 2  T or staggered junction            Slight               Daylight
# 3  T or staggered junction           Serious               Daylight
# 4               Crossroads           Serious  Darkness - lights lit
#
#   Local_Authority_(District)  Number_of_Casualties  Number_of_Vehicles  \
# 0     Kensington and Chelsea                     1                   2
# ...

# %%
## count of Junction Detail:

# %%
df['Junction_Detail'].value_counts()
# Out:
# Junction_Detail
# Not at junction or within 20 metres    123094
# T or staggered junction                 96718
# Crossroads                              29948
# Roundabout                              27264
# Private drive or entrance               10875
# Other junction                           8315
# Slip road                                4265
# More than 4 arms (not roundabout)        4148
# Mini-roundabout                          3346
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
ai = sns.countplot(x='Junction_Detail',data=df,hue='Junction_Detail')
for i in ai.containers:
  plt.bar_label(i)
plt.xticks(rotation=90)
plt.title('Count of Junction Detail',color='darkred')
ai.axes.set_facecolor('cyan')
plt.gcf().set_facecolor('pink')
plt.show()

# %%
## count of Accident Severity:

# %%
df['Accident_Severity'].value_counts()
# Out:
# Accident_Severity
# Slight     263280
# Serious     40740
# Fatal        3953
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
ji = sns.countplot(x='Accident_Severity',data=df,hue='Accident_Severity')
for i in ji.containers:
  plt.bar_label(i)
plt.title('Count of Accident Severity',color='blue')
ji.axes.set_facecolor('lightgreen')
plt.gcf().set_facecolor('yellow')
plt.show()

# %%
## percentage of Accident severity:

# %%
u = df['Accident_Severity'].value_counts()

# %%
u
# Out:
# Accident_Severity
# Slight     263280
# Serious     40740
# Fatal        3953
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.pie(u.values,labels=u.index,autopct='%.1f',labeldistance=1.05,shadow=True)
plt.title('Percentage of Accident Severity',color='blue')
plt.show()

# %%
## count of light conditions:

# %%
df['Light_Conditions'].value_counts()
# Out:
# Light_Conditions
# Daylight                       227286
# Darkness - lights lit           60093
# Darkness - no lighting          16528
# Darkness - lighting unknown      2924
# Darkness - lights unlit          1142
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
t= sns.countplot(x='Light_Conditions',data=df,hue='Light_Conditions')
for i in t.containers:
  plt.bar_label(i)
plt.title('Count of Light conditions',color='darkgreen')
t.axes.set_facecolor('yellow')
plt.gcf().set_facecolor('lightgreen')
plt.show()

# %%
## count of Top 10 Locat Authority District:

# %%
v= df['Local_Authority_(District)'].value_counts().nlargest(10)

# %%
plt.figure(figsize=(12,8))
ti = sns.barplot(x=v.index,y=v.values,hue=v.index)
for i in ti.containers:
  plt.bar_label(i)
plt.title('Top 10 Local authoritiy district',color='blue')
ti.axes.set_facecolor('lightblue')
plt.gcf().set_facecolor('lightyellow')
plt.show()

# %%
## count of Road Surface Conditions:

# %%
df['Road_Surface_Conditions'].value_counts()
# Out:
# Road_Surface_Conditions
# Dry                     209284
# Wet or damp              81479
# Frost or ice             12078
# Snow                      4758
# Flood over 3cm. deep       374
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
tii = sns.countplot(x='Road_Surface_Conditions',data=df,hue='Road_Surface_Conditions')
for i in tii.containers:
  plt.bar_label(i)
plt.title('Count of Road Surface Conditions',color='darkred')
tii.axes.set_facecolor('lightgrey')
plt.gcf().set_facecolor('lightpink')
plt.show()

# %%
## percentage of Road surface conditions:

# %%
n = df['Road_Surface_Conditions'].value_counts()

# %%
n
# Out:
# Road_Surface_Conditions
# Dry                     209284
# Wet or damp              81479
# Frost or ice             12078
# Snow                      4758
# Flood over 3cm. deep       374
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.pie(n.values,labels=n.index,autopct='%.1f',labeldistance=1.05,shadow=True)
centre_circle = plt.Circle((0,0),radius=0.50,fc='white')
fig = plt.gcf()
plt.gca().add_artist(centre_circle)
plt.show
plt.title('Percentage of Road Surface Conditions',color='blue')
plt.show()

# %%
df.head()
# Out:
#   Accident_Index Accident Date  Year          Junction_Control  \
# 0  200901BS70001    2021-01-01  2021  Give way or uncontrolled
# 1  200901BS70002    2021-01-05  2021  Give way or uncontrolled
# 2  200901BS70003    2021-01-04  2021  Give way or uncontrolled
# 3  200901BS70004    2021-01-05  2021       Auto traffic signal
# 4  200901BS70005    2021-01-06  2021       Auto traffic signal
#
#            Junction_Detail Accident_Severity       Light_Conditions  \
# 0  T or staggered junction           Serious               Daylight
# 1               Crossroads           Serious               Daylight
# 2  T or staggered junction            Slight               Daylight
# 3  T or staggered junction           Serious               Daylight
# 4               Crossroads           Serious  Darkness - lights lit
#
#   Local_Authority_(District)  Number_of_Casualties  Number_of_Vehicles  \
# 0     Kensington and Chelsea                     1                   2
# ...

# %%
df['Road_Type'].value_counts()
# Out:
# Road_Type
# Single carriageway    232146
# Dual carriageway       45467
# Roundabout             20929
# One way street          6197
# Slip road               3234
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
bi = sns.countplot(x='Road_Type',data=df,hue='Road_Type')
for i in bi.containers:
  plt.bar_label(i)
plt.title('Count of Road Type',color='red')
bi.axes.set_facecolor('lightblue')
plt.gcf().set_facecolor('lightyellow')
plt.show()

# %%
## Percentage of Road type:

# %%
c= df['Road_Type'].value_counts()

# %%
c
# Out:
# Road_Type
# Single carriageway    232146
# Dual carriageway       45467
# Roundabout             20929
# One way street          6197
# Slip road               3234
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.pie(c.values,labels=c.index,autopct='%.1f',labeldistance=1.05,shadow=True)
plt.show()

# %%
## Percentage of Urban and Rural areas:

# %%
x= df['Urban_or_Rural_Area'].value_counts()

# %%
x
# Out:
# Urban_or_Rural_Area
# Urban    198532
# Rural    109441
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.pie(x.values,labels=x.index,autopct='%.1f',labeldistance=1.05,shadow=True,colors=['red','green'])
plt.title('percentage of Urban and Rural Areas',color='red')
plt.show()

# %%
df.head()
# Out:
#   Accident_Index Accident Date  Year          Junction_Control  \
# 0  200901BS70001    2021-01-01  2021  Give way or uncontrolled
# 1  200901BS70002    2021-01-05  2021  Give way or uncontrolled
# 2  200901BS70003    2021-01-04  2021  Give way or uncontrolled
# 3  200901BS70004    2021-01-05  2021       Auto traffic signal
# 4  200901BS70005    2021-01-06  2021       Auto traffic signal
#
#            Junction_Detail Accident_Severity       Light_Conditions  \
# 0  T or staggered junction           Serious               Daylight
# 1               Crossroads           Serious               Daylight
# 2  T or staggered junction            Slight               Daylight
# 3  T or staggered junction           Serious               Daylight
# 4               Crossroads           Serious  Darkness - lights lit
#
#   Local_Authority_(District)  Number_of_Casualties  Number_of_Vehicles  \
# 0     Kensington and Chelsea                     1                   2
# ...

# %%
## Count of weather conditions:

# %%
df['Weather_Conditions'].value_counts()
# Out:
# Weather_Conditions
# Fine no high winds       250553
# Raining no high winds     34877
# Other                      8802
# Snowing no high winds      4839
# Raining + high winds       3526
# Fine + high winds          3148
# Fog or mist                1690
# Snowing + high winds        538
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
gi = sns.countplot(x='Weather_Conditions',data=df,hue='Weather_Conditions')
for i in gi.containers:
  plt.bar_label(i)
plt.xticks(rotation=90)
plt.title('Count of weather conditions',color='blue')
gi.axes.set_facecolor('cyan')
plt.gcf().set_facecolor('lightgreen')
plt.show()

# %%
## Count of Vehicle type:

# %%
df['Vehicle_Type'].value_counts()
# Out:
# Vehicle_Type
# Car                                      239794
# Van / Goods 3.5 tonnes mgw or under       15695
# Motorcycle over 500cc                     11226
# Bus or coach (17 or more pass seats)       8686
# Motorcycle 125cc and under                 6852
# Goods 7.5 tonnes mgw and over              6532
# Taxi/Private hire car                      5543
# Motorcycle 50cc and under                  3703
# Motorcycle over 125cc and up to 500cc      3285
# Other vehicle                              2516
# Goods over 3.5t. and under 7.5t            2502
# Minibus (8 - 16 passenger seats)            821
# Agricultural vehicle                        749
# Pedal cycle                                  66
# Ridden horse                                  3
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
y = sns.countplot(x='Vehicle_Type',data=df,hue='Vehicle_Type')
for i in y.containers:
  plt.bar_label(i)
plt.title('count of Vehicle Type',color='red')
plt.xticks(rotation=90)
y.axes.set_facecolor('lightyellow')
plt.gcf().set_facecolor('lightgreen')
plt.show()

# %%
## How much people are injured?

# %%
casulities = df.groupby("Accident_Severity")["Number_of_Casualties"].sum().reset_index()

# %%
casulities
# Out:
#   Accident_Severity  Number_of_Casualties
# 0             Fatal                  7135
# 1           Serious                 59312
# 2            Slight                351436

# %%
plt.figure(figsize=(12,8))
sns.lineplot(y='Number_of_Casualties',x='Accident_Severity',data=casulities)
plt.title('Injured people',color='red')
plt.show()

# %%
## Number of vehicles by vehicle type:

# %%
df.head()
# Out:
#   Accident_Index Accident Date  Year          Junction_Control  \
# 0  200901BS70001    2021-01-01  2021  Give way or uncontrolled
# 1  200901BS70002    2021-01-05  2021  Give way or uncontrolled
# 2  200901BS70003    2021-01-04  2021  Give way or uncontrolled
# 3  200901BS70004    2021-01-05  2021       Auto traffic signal
# 4  200901BS70005    2021-01-06  2021       Auto traffic signal
#
#            Junction_Detail Accident_Severity       Light_Conditions  \
# 0  T or staggered junction           Serious               Daylight
# 1               Crossroads           Serious               Daylight
# 2  T or staggered junction            Slight               Daylight
# 3  T or staggered junction           Serious               Daylight
# 4               Crossroads           Serious  Darkness - lights lit
#
#   Local_Authority_(District)  Number_of_Casualties  Number_of_Vehicles  \
# 0     Kensington and Chelsea                     1                   2
# ...

# %%
## which day accidents are happened most?

# %%
df['accident_day'].value_counts()
# Out:
# accident_day
# Saturday     50529
# Wednesday    46386
# Thursday     46381
# Friday       45649
# Tuesday      43918
# Sunday       41566
# Monday       33544
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
f = sns.countplot(x='accident_day',data=df,hue='accident_day',order=df['accident_day'].value_counts().index[:])
for i in f.containers:
  plt.bar_label(i)
plt.title('Which day accidents are happened most:',color='red')
plt.show()

# %%
## which month accidents are happened most?

# %%
df['accident_month'] = df['Accident Date'].dt.month_name()

# %%
df['accident_month'].value_counts()
# Out:
# accident_month
# November     29095
# October      28368
# July         26953
# September    26752
# June         26748
# May          26183
# March        25543
# August       25503
# April        24225
# January      23384
# December     23334
# February     21885
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
fi = sns.countplot(x='accident_month',data=df,hue='accident_month',order=df['accident_month'].value_counts().index[::-1])
for i in fi.containers:
  plt.bar_label(i)
plt.title('Which month accidents are happend most?',color='red')
plt.show()

# %%
## which year accidents are happened most?

# %%
df['Year'].value_counts()
# Out:
# Year
# 2021    163554
# 2022    144419
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
ci = sns.countplot(x='Year',data=df,palette='crest')
for i in ci.containers:
  plt.bar_label(i)
plt.title('Which year accidents are happened most?')
plt.show()
# Out:
# C:\Users\SOFT\AppData\Local\Temp\ipykernel_14480\3120237937.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ci = sns.countplot(x='Year',data=df,palette='crest')

# %%
## percentage of accidents of year:

# %%
m = df['Year'].value_counts()

# %%
m
# Out:
# Year
# 2021    163554
# 2022    144419
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.pie(m.values,labels=m.index,autopct='%.1f',labeldistance=1.05,shadow=True)
plt.title('Percentage of accidents of year',color='red')
plt.show()

# %%
sum_of_casualties_by_month = df.groupby('accident_month')['Number_of_Casualties'].sum().reset_index()

# %%
sum_of_casualties_by_month
# Out:
#    accident_month  Number_of_Casualties
# 0           April                 33102
# 1          August                 35593
# 2        December                 31776
# 3        February                 29452
# 4         January                 31336
# 5            July                 36883
# 6            June                 35958
# 7           March                 34390
# 8             May                 35627
# 9        November                 39414
# 10        October                 38396
# 11      September                 35956

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x='accident_month',y='Number_of_Casualties',data=df)
plt.title('sum of casualties by month',color='red')
plt.show()

# %%
sum_casualties_year = df.groupby('Year')['Number_of_Casualties'].sum().reset_index()

# %%
sum_casualties_year
# Out:
#    Year  Number_of_Casualties
# 0  2021                222146
# 1  2022                195737

# %%
plt.figure(figsize=(12,8))
d = sns.barplot(x='Year',y='Number_of_Casualties',data=df,hue='Year')
for i in d.containers:
  plt.bar_label(i)
plt.title('sum of casualties by year')
plt.show()

# %%
## avg of casaulties by month

# %%
avg_casualties_month = df.groupby('accident_month')['Number_of_Casualties'].mean().reset_index()

# %%
avg_casualties_month
# Out:
#    accident_month  Number_of_Casualties
# 0           April              1.366440
# 1          August              1.395640
# 2        December              1.361790
# 3        February              1.345762
# 4         January              1.340062
# 5            July              1.368419
# 6            June              1.344325
# 7           March              1.346357
# 8             May              1.360692
# 9        November              1.354666
# 10        October              1.353497
# 11      September              1.344049

# %%
plt.figure(figsize=(12,8))
di= sns.barplot(x='accident_month',y='Number_of_Casualties',data=avg_casualties_month,hue='accident_month')
for i in di.containers:
  plt.bar_label(i)
plt.title('Average of casualties by month',color='red')
plt.show()

# %%
## average of casualties by year:

# %%
avg_casualties_year = df.groupby('Year')['Number_of_Casualties'].mean().reset_index()

# %%
avg_casualties_year
# Out:
#    Year  Number_of_Casualties
# 0  2021              1.358243
# 1  2022              1.355341

# %%
plt.figure(figsize=(12,8))
mi= sns.barplot(x='Year',y='Number_of_Casualties',data=avg_casualties_year,hue='Year')
for i in mi.containers:
  plt.bar_label(i)
plt.title('Average of casualties by year',color='red')
plt.show()

# %%
df
# Out:
#        Accident_Index Accident Date  Year              Junction_Control  \
# 0       200901BS70001    2021-01-01  2021      Give way or uncontrolled
# 1       200901BS70002    2021-01-05  2021      Give way or uncontrolled
# 2       200901BS70003    2021-01-04  2021      Give way or uncontrolled
# 3       200901BS70004    2021-01-05  2021           Auto traffic signal
# 4       200901BS70005    2021-01-06  2021           Auto traffic signal
# ...               ...           ...   ...                           ...
# 307968  201091NM01760    2022-02-18  2022  Data missing or out of range
# 307969  201091NM01881    2022-02-21  2022  Data missing or out of range
# 307970  201091NM01935    2022-02-23  2022      Give way or uncontrolled
# 307971  201091NM01964    2022-02-23  2022      Give way or uncontrolled
# 307972  201091NM02142    2022-02-28  2022      Give way or uncontrolled
#
#                             Junction_Detail Accident_Severity  \
# ...

# %%
sns.countplot(x="Speed_limit",data=df)
# Out:
# <Axes: xlabel='Speed_limit', ylabel='count'>

# %%
# df['hour'] = df['hour'].astype(int)

df["hour"] = pd.to_numeric(df["hour"])
df["hour"].value_counts()
# Out:
# hour
# 17.0    26964
# 16.0    24903
# 15.0    24151
# 8.0     22552
# 18.0    21063
# 14.0    19067
# 13.0    18971
# 12.0    18342
# 11.0    16141
# 19.0    15851
# 9.0     15560
# 10.0    13791
# 7.0     12560
# 20.0    11402
# 21.0     9443
# 22.0     8146
# 23.0     6400
# 6.0      5274
# 0.0      4667
# 1.0      3533
# 2.0      2652
# 5.0      2491
# 3.0      2311
# 4.0      1721
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
ei= sns.countplot(x='hour',data=df,palette=['black'],order=df["hour"].value_counts().index[::-1])
for i in ei.containers:
    plt.bar_label(i,rotation=90,label_type='center',color='white')
plt.title('Time of accidents',color='red')    
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\SOFT\AppData\Local\Temp\ipykernel_14480\1919870578.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ei= sns.countplot(x='hour',data=df,palette=['black'],order=df["hour"].value_counts().index[::-1])
# C:\Users\SOFT\AppData\Local\Temp\ipykernel_14480\1919870578.py:2: UserWarning:
# The palette list has fewer values (1) than needed (24) and will cycle, which may produce an uninterpretable plot.
#   ei= sns.countplot(x='hour',data=df,palette=['black'],order=df["hour"].value_counts().index[::-1])
